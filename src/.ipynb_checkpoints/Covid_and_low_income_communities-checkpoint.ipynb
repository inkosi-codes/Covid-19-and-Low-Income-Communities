# %% [markdown]
# ## Create Dependencies

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
import scipy.stats as st
import numpy as np
import requests as rq
import random as rnd
import gmaps
import os
import io
import json
import time
from datetime import datetime
# Import API key
#import config

# Configure gmaps
gkey = config.gkey
gmaps.configure(api_key=gkey)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-6d862045ac6c> in <module>
#      17
#      18 # Configure gmaps
# ---> 19 gkey = config.gkey
#      20 gmaps.configure(api_key=gkey)
#
# NameError: name 'config' is not defined

# %% [markdown]
# ## Create and set the path

# %%
notebook_path = os.getcwd()
parent_dir = notebook_path[0:-4]

# %% [markdown]
# ## Store csv filenames. Iterate through the filename list and get csv from path and store in variables

# %%
dataset_filelist = ["1_county_level_confirmed_cases.csv","2_cases_and_deaths_by_county_timeseries.csv","weekly-claims-by-county-twc.csv","texas_county_med_income.csv"]
for csv in dataset_filelist:   
    for root, dirs, files in os.walk(parent_dir):
        if csv in files:
            if csv == dataset_filelist[0]:
                covid_dataset1 = (os.path.join(root, csv))
            elif csv == dataset_filelist[1]:
               covid_dataset2 =  (os.path.join(root, csv))
            elif csv == dataset_filelist[2]:
               unemployment_dataset =  (os.path.join(root, csv))
            else:
                texas_median_income = (os.path.join(root, csv))

# %% [markdown]
# ## Use pandas and read contents of csv into a DataFrame

# %%
ConfirmedByCounty_Covid = pd.read_csv('https://query.data.world/s/tmtcsyi5cadisfgsziloo4c7sesaon')
CaseDeathsBy_County_timeseries = pd.read_csv('https://query.data.world/s/ipaqguramdyfp27ppx72n3sgtkj6xu', parse_dates=['date'])
unemployment_dataset = pd.read_csv(unemployment_dataset)
texas_median_income = pd.read_csv(texas_median_income)

# %% [markdown]
# ## Remove ("$",",") characters from the Texas Median Income dataset and convert to float

# %%
texas_median_income['Median Household Income'] = texas_median_income['Median Household Income'].str.replace('$','').str.replace(',','').astype(float)

# %%
texas_median_income.head()
# Out:
#      County  Median Household Income
# 0  Anderson                  45969.0
# 1   Andrews                  84946.0
# 2  Angelina                  46653.0
# 3   Aransas                  46912.0
# 4    Archer                  61190.0

# %%
texas_low_income = texas_median_income.loc[(texas_median_income['Median Household Income'] > 57000)]
texas_low_income.describe()
# Out:
#        Median Household Income
# count                56.000000
# mean              69560.303571
# std               11444.745846
# min               57052.000000
# 25%               60789.500000
# 50%               66080.000000
# 75%               76322.000000
# max              102858.000000

# %% [markdown]
# ## Incomes that qualify as low imcome per HUD data. Less than or equal to 57K but greater than 36K

# %%
texas_low_income = texas_median_income.loc[(texas_median_income['Median Household Income'] <= 57000) & (texas_median_income['Median Household Income'] > 36000)]
texas_low_income.head()
# Out:
#      County  Median Household Income
# 0  Anderson                  45969.0
# 2  Angelina                  46653.0
# 3   Aransas                  46912.0
# 6  Atascosa                  50594.0
# 8    Bailey                  45051.0

# %% [markdown]
# ## Incomes that qualify as very low imcome per HUD data. Less than or equal to 36K but greater than 26K

# %%
texas_verylow_income = texas_median_income.loc[(texas_median_income['Median Household Income'] <= 36000) & (texas_median_income['Median Household Income'] > 26000)]
texas_verylow_income.head()
# Out:
#        County  Median Household Income
# 23     Brooks                  30116.0
# 65      Duval                  35156.0
# 95       Hall                  32597.0
# 161  Maverick                  35594.0
# 163    Menard                  35881.0

# %% [markdown]
# ## Covid-19 Dataset that gives most recent case and death numbers as of 2020-11-13
# * Cleansed Data to get rid of one row in Latitude and Longitude that had NaN

# %%
Texas_ConfirmedByCounty_Covid = ConfirmedByCounty_Covid.loc[ConfirmedByCounty_Covid['state'] == 'Texas'].dropna(subset=['lat','lon'])
Texas_ConfirmedByCounty_Covid.head()
# Out:
#                   last_update location_type  state county_name  \
# 2599  2020-11-19 13:26:25 UTC        county  Texas    Anderson
# 2600  2020-11-19 13:26:25 UTC        county  Texas     Andrews
# 2601  2020-11-19 13:26:25 UTC        county  Texas    Angelina
# 2602  2020-11-19 13:26:25 UTC        county  Texas     Aransas
# 2603  2020-11-19 13:26:25 UTC        county  Texas      Archer
#
#          county_name_long  fips_code        lat         lon NCHS_urbanization  \
# 2599  Anderson, Texas, US    48001.0  31.815347  -95.653548      Micropolitan
# 2600   Andrews, Texas, US    48003.0  32.304686 -102.637655      Micropolitan
# 2601  Angelina, Texas, US    48005.0  31.254573  -94.609015      Micropolitan
# 2602   Aransas, Texas, US    48007.0  28.105562  -96.999505      Medium metro
# 2603    Archer, Texas, US    48009.0  33.615700  -98.687546       Small metro
#
#       total_population  confirmed  confirmed_per_100000  deaths  \
# ...

# %%
Texas_ConfirmedByCounty_Covid = Texas_ConfirmedByCounty_Covid.drop(columns=["location_type","state","county_name_long","fips_code"])

# %%
covid_cumlative_groupby = Texas_ConfirmedByCounty_Covid.groupby('NCHS_urbanization')
covid_cumlative_groupby['county_name'].count()
# Out:
# NCHS_urbanization
# Large central metro      6
# Large fringe metro      29
# Medium metro            25
# Micropolitan            46
# Non-core               126
# Small metro             22
# Name: county_name, dtype: int64

# %%
Texas_ConfirmedByCounty_Covid.loc[Texas_ConfirmedByCounty_Covid['NCHS_urbanization'] == 'Large central metro'].sort_values('total_population',ascending=False)
# Out:
#                   last_update county_name        lat        lon  \
# 2699  2020-11-19 13:26:25 UTC      Harris  29.858649 -95.393395
# 2655  2020-11-19 13:26:25 UTC      Dallas  32.766706 -96.777960
# 2818  2020-11-19 13:26:25 UTC     Tarrant  32.771438 -97.291016
# 2613  2020-11-19 13:26:25 UTC       Bexar  29.449287 -98.520197
# 2825  2020-11-19 13:26:25 UTC      Travis  30.334320 -97.785356
# 2641  2020-11-19 13:26:25 UTC      Collin  33.188201 -96.572644
#
#         NCHS_urbanization  total_population  confirmed  confirmed_per_100000  \
# 2699  Large central metro         4602523.0     177466               3855.84
# 2655  Large central metro         2586552.0     111960               4328.54
# 2818  Large central metro         2019977.0      85759               4245.54
# 2613  Large central metro         1925865.0      70894               3681.15
# 2825  Large central metro         1203166.0      35326               2936.09
# ...

# %%
combined = covid_cumlative_groupby['confirmed','deaths'].sum()
combined.plot(kind='bar', stacked=True)
# Out:
# C:\Users\mike1\anaconda3\envs\VirCondaEnv\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
# <AxesSubplot:xlabel='NCHS_urbanization'>

# %%
urban_death = covid_cumlative_groupby['deaths'].mean()

# %%
urban_death
# Out:
# NCHS_urbanization
# Large central metro    1241.333333
# Large fringe metro       80.068966
# Medium metro            240.320000
# Micropolitan             43.217391
# Non-core                 10.238095
# Small metro              58.272727
# Name: deaths, dtype: float64

# %%
urban_cases.plot.bar()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-31bd5f2445fa> in <module>
# ----> 1 urban_cases.plot.bar()
#
# NameError: name 'urban_cases' is not defined

# %%
covid_cumlative_groupby['confirmed'].mean()
# Out:
# NCHS_urbanization
# Large central metro    83898.000000
# Large fringe metro      4972.862069
# Medium metro           10720.480000
# Micropolitan            1456.217391
# Non-core                 354.007937
# Small metro             2925.181818
# Name: confirmed, dtype: float64

# %% [markdown]
# ## Select only data related to the state of Texas and drop all column with headers starting with "new"

# %%
columns_todrop = []
Texas_CaseDeathsBy_County_timeseries = CaseDeathsBy_County_timeseries.loc[(CaseDeathsBy_County_timeseries['state'] == 'Texas') & (CaseDeathsBy_County_timeseries['location_name'] != 'Unassigned') & (CaseDeathsBy_County_timeseries['location_name'] != 'Out of TX')]
Texas_CaseDeathsBy_County_timeseries = Texas_CaseDeathsBy_County_timeseries.loc[Texas_CaseDeathsBy_County_timeseries['date'] >= '2020-03-01']
for column in Texas_CaseDeathsBy_County_timeseries.columns:
    if column.startswith('new'):
        columns_todrop.append(column)
for drop in columns_todrop:
    Texas_CaseDeathsBy_County_timeseries = Texas_CaseDeathsBy_County_timeseries.drop(columns=drop)
Texas_CaseDeathsBy_County_timeseries.head()
# Out:
#              uid location_type  fips_code location_name  state       date  \
# 786145  84048001        county    48001.0      Anderson  Texas 2020-03-01
# 786146  84048001        county    48001.0      Anderson  Texas 2020-03-02
# 786147  84048001        county    48001.0      Anderson  Texas 2020-03-03
# 786148  84048001        county    48001.0      Anderson  Texas 2020-03-04
# 786149  84048001        county    48001.0      Anderson  Texas 2020-03-05
#
#         total_population  cumulative_cases  cumulative_cases_per_100_000  \
# 786145           57863.0                 0                           0.0
# 786146           57863.0                 0                           0.0
# 786147           57863.0                 0                           0.0
# 786148           57863.0                 0                           0.0
# 786149           57863.0                 0                           0.0
#
#         cumulative_deaths  cumulative_deaths_per_100_000
# ...

# %% [markdown]
# ## Drop all other unused columns

# %%
Texas_CaseDeathsBy_County_timeseries = Texas_CaseDeathsBy_County_timeseries.drop(columns=["uid","location_type","state"]).set_index('date')

# %%
Texas_CaseDeathsBy_County_timeseries
# Out:
#             fips_code location_name  total_population  cumulative_cases  \
# date
# 2020-03-01    48001.0      Anderson           57863.0                 0
# 2020-03-02    48001.0      Anderson           57863.0                 0
# 2020-03-03    48001.0      Anderson           57863.0                 0
# 2020-03-04    48001.0      Anderson           57863.0                 0
# 2020-03-05    48001.0      Anderson           57863.0                 0
# ...               ...           ...               ...               ...
# 2020-11-14    48507.0        Zavala           12131.0               527
# 2020-11-15    48507.0        Zavala           12131.0               527
# 2020-11-16    48507.0        Zavala           12131.0               527
# 2020-11-17    48507.0        Zavala           12131.0               534
# 2020-11-18    48507.0        Zavala           12131.0               546
#
#             cumulative_cases_per_100_000  cumulative_deaths  \
# date
# ...

# %% [markdown]
# ## needed this data for my charts..should be similar to what Jazlyn puts together

# %%
test = Texas_CaseDeathsBy_County_timeseries[(Texas_CaseDeathsBy_County_timeseries.index + pd.Timedelta(days=1)).day == 1]
test.head(50)
test = Texas_CaseDeathsBy_County_timeseries[(Texas_CaseDeathsBy_County_timeseries.index + pd.Timedelta(days=1)).day == 1]
test2 = Texas_CaseDeathsBy_County_timeseries.loc['2020-11-11']
test = test.append(test2)

date_list = ['2020-03-31','2020-04-30','2020-05-31','2020-06-30','2020-07-31','2020-08-31','2020-09-30','2020-10-31','2020-11-11']
cumulative_numbers = []
cumulative_numbers.append(test.loc['2020-03-31']['cumulative_cases'].sum())
for d in range(len(date_list)-1):
    cumulative_numbers.append((test.loc[date_list[d+1]]['cumulative_cases'].sum()) - (test.loc[date_list[d]]['cumulative_cases'].sum()))
    print(cumulative_numbers)
# Out:
# [3809, 24918, 35925, 98408, 275233, 194446, 140280, 159242, 90075]

# %%
test
test.loc[] == 'Anderson'
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-114-3b0b8fb893cd> in <module>
#       1 test
# ----> 2 test.loc[index[2]] == 'Anderson'
#
# NameError: name 'index' is not defined

# %% [markdown]
# ## Cleaning and setting up unemployment dataframes

# %%
unemployment_claims = unemployment_dataset.copy()
unemployment_claims = unemployment_claims.transpose()
unemployment_claims = unemployment_claims.fillna(0)

# %%
unemployment_claims.columns = [''] * len(unemployment_claims.columns)
unemployment_header = unemployment_claims.iloc[0]
unemployment_claims = unemployment_claims[1:]
unemployment_claims.columns = unemployment_header
unemployment_claims.index.names = ['Date']
unemployment_claims.columns.names = ['']
unemployment_claims.head()
# Out:
#            Anderson Andrews Angelina Aransas Archer Armstrong Atascosa Austin  \
# Date
# 11/7/2020        51      12       83      20      5         0       57     29
# 10/31/2020       42      17       77      32      3         1       46     28
# 10/24/2020       79      17       89      22      6         0       36     23
# 10/17/2020       54      17       80      40      5         1       35     26
# 10/10/2020       63      30       98      18     10         2       40     32
#
#            Bailey Bandera  ... Willacy Williamson Wilson Winkler Wise Wood  \
# Date                       ...
# 11/7/2020      12      18  ...      26        455     32      11   52   39
# 10/31/2020      3      23  ...      24        422     28       7   74   31
# 10/24/2020      1      13  ...      51        409     34       8   65   33
# 10/17/2020      4      24  ...      43        434     30      15   45   26
# 10/10/2020      3      11  ...      24        484     41      11   57   38
#
# ...

# %%
unemployment_claims.index = pd.to_datetime(unemployment_claims.index)
unemployment_claims.head()
# Out:
#            Anderson Andrews Angelina Aransas Archer Armstrong Atascosa Austin  \
# Date
# 2020-11-07       51      12       83      20      5         0       57     29
# 2020-10-31       42      17       77      32      3         1       46     28
# 2020-10-24       79      17       89      22      6         0       36     23
# 2020-10-17       54      17       80      40      5         1       35     26
# 2020-10-10       63      30       98      18     10         2       40     32
#
#            Bailey Bandera  ... Willacy Williamson Wilson Winkler Wise Wood  \
# Date                       ...
# 2020-11-07     12      18  ...      26        455     32      11   52   39
# 2020-10-31      3      23  ...      24        422     28       7   74   31
# 2020-10-24      1      13  ...      51        409     34       8   65   33
# 2020-10-17      4      24  ...      43        434     30      15   45   26
# 2020-10-10      3      11  ...      24        484     41      11   57   38
#
# ...

# %%
anderson_sum = unemployment_claims_monthly["Anderson"].sum
anderson_sum
unemployment_claims_monthly.sum(axis=1)
# Out:
# Date
# 2020-03-31    447963.0
# 2020-04-30    843167.0
# 2020-05-31    591316.0
# 2020-06-30    319165.0
# 2020-07-31    323837.0
# 2020-08-31    246138.0
# 2020-09-30    165862.0
# 2020-10-31    170999.0
# 2020-11-30     32887.0
# Freq: M, dtype: float64

# %% [markdown]
# ## Monthly claims for all texas counties

# %%
######NEED THIS IN A DATAFRAME WITH COLUMN HEADINGS IN ORDER TO MERGE WITH UNEMPLOYMENT DATA  
unemployment_claims_monthly = unemployment_claims.resample('M').sum()
unemployment_claims_monthly_by_county = unemployment_claims_monthly.sum(axis=0)
# unemployment_claims_monthly_by_county = unemployment_claims_monthly.sum(axis=0)
# unemployment_claims_monthly

# unemployment_claims_monthly_by_county_df = pd.DataFrame({'Claims Per Month': unemployment_claims_monthly_by_county})
# unemployment_claims_monthly_by_county_df
unemployment_claims_monthly_by_county_list = unemployment_claims_monthly_by_county.values.tolist()
counties_list = unemployment_dataset.copy()['County']

counties_list
unemployment_claims_monthly_by_county_df = pd.DataFrame({'County':counties_list, 'Claims Per Month': unemployment_claims_monthly_by_county_list})
unemployment_claims_monthly_by_county_df.tail(50)
# Out:
#            County  Claims Per Month
# 204  San Patricio            7992.0
# 205      San Saba             269.0
# 206    Schleicher             155.0
# 207        Scurry            1371.0
# 208   Shackelford             208.0
# 209        Shelby            1830.0
# 210       Sherman              48.0
# 211         Smith           22451.0
# 212     Somervell             610.0
# 213         Starr            9393.0
# 214      Stephens             711.0
# 215      Sterling              81.0
# 216     Stonewall              53.0
# 217        Sutton             241.0
# 218       Swisher             276.0
# 219       Tarrant          246152.0
# 220        Taylor           11227.0
# 221       Terrell              31.0
# 222         Terry             838.0
# 223  Throckmorton              58.0
# 224         Titus            2379.0
# 225     Tom Green            9797.0
# 226        Travis          138142.0
# 227       Trinity            1091.0
# 228         Tyler            1775.0
# ...

# %% [markdown]
# ##  Monthly claim totals for each month

# %%
claims_monthly_totals = unemployment_claims_monthly.sum(axis=1)

total_claims_per_month_df = pd.DataFrame({'Claims Per Month': claims_monthly_totals})
total_claims_per_month_df.head(20)
# Out:
#             Claims Per Month
# Date
# 2020-03-31          447963.0
# 2020-04-30          843167.0
# 2020-05-31          591316.0
# 2020-06-30          319165.0
# 2020-07-31          323837.0
# 2020-08-31          246138.0
# 2020-09-30          165862.0
# 2020-10-31          170999.0
# 2020-11-30           32887.0

# %% [markdown]
# ## Low and Very Low  income county data to merge with unemployment data

# %%
#original claims dataset..merge with low income county and very low  list
claims_data = unemployment_dataset.copy()
claims_data_very_low = unemployment_dataset.copy()

# claims_data_merged
claims_data_merged = claims_data.merge(texas_low_income, left_on='County', right_on='County')
claims_data_merged_very_low = claims_data.merge(texas_verylow_income, left_on='County', right_on='County')


#claims_data_merged
claims_data_merged_very_low
# Out:
#      County  11/7/2020  10/31/2020  10/24/2020  10/17/2020  10/10/2020  \
# 0    Brooks        7.0         9.0         8.0        13.0        12.0
# 1     Duval       21.0        10.0        16.0         9.0        19.0
# 2      Hall        2.0         2.0         1.0         4.0         3.0
# 3  Maverick      138.0       241.0       111.0       100.0        99.0
# 4    Menard        2.0         1.0         2.0         NaN         1.0
# 5     Starr      178.0       124.0       152.0       143.0       139.0
# 6   Willacy       26.0        24.0        51.0        43.0        24.0
# 7    Zapata       19.0        20.0        27.0        27.0        22.0
# 8    Zavala       21.0        11.0        18.0        12.0        16.0
#
#    10/3/2020  9/26/2020  9/19/2020  9/12/2020  ...  5/2/2020  4/25/2020  \
# 0       14.0       15.0        9.0        7.0  ...      33.0       34.0
# 1       18.0       17.0       15.0       21.0  ...      93.0       62.0
# ...

# %% [markdown]
# ## Removing an unnecessary column that will cause a problem in a future step

# %%
claims_data_merged = claims_data_merged.drop(columns=['Median Household Income'])
claims_data_merged_very_low = claims_data_merged_very_low.drop(columns=['Median Household Income'])

claims_data_merged
claims_data_merged_very_low
# Out:
#      County  11/7/2020  10/31/2020  10/24/2020  10/17/2020  10/10/2020  \
# 0    Brooks        7.0         9.0         8.0        13.0        12.0
# 1     Duval       21.0        10.0        16.0         9.0        19.0
# 2      Hall        2.0         2.0         1.0         4.0         3.0
# 3  Maverick      138.0       241.0       111.0       100.0        99.0
# 4    Menard        2.0         1.0         2.0         NaN         1.0
# 5     Starr      178.0       124.0       152.0       143.0       139.0
# 6   Willacy       26.0        24.0        51.0        43.0        24.0
# 7    Zapata       19.0        20.0        27.0        27.0        22.0
# 8    Zavala       21.0        11.0        18.0        12.0        16.0
#
#    10/3/2020  9/26/2020  9/19/2020  9/12/2020  ...  5/9/2020  5/2/2020  \
# 0       14.0       15.0        9.0        7.0  ...      45.0      33.0
# 1       18.0       17.0       15.0       21.0  ...      61.0      93.0
# ...

# %% [markdown]
# ## Transpose dataframes

# %%
claims_data_merged = claims_data_merged.transpose()
claims_data_merged = claims_data_merged.fillna(0)

claims_data_merged_very_low = claims_data_merged_very_low.transpose()
claims_data_merged_very_low = claims_data_merged_very_low.fillna(0)

claims_data_merged.head()
claims_data_merged_very_low.head()
# Out:
#                  0      1     2         3       4      5        6       7  \
# County      Brooks  Duval  Hall  Maverick  Menard  Starr  Willacy  Zapata
# 11/7/2020        7     21     2       138       2    178       26      19
# 10/31/2020       9     10     2       241       1    124       24      20
# 10/24/2020       8     16     1       111       2    152       51      27
# 10/17/2020      13      9     4       100       0    143       43      27
#
#                  8
# County      Zavala
# 11/7/2020       21
# 10/31/2020      11
# 10/24/2020      18
# 10/17/2020      12

# %% [markdown]
# ## Clean dataframes

# %%
claims_data_merged.columns = [''] * len(claims_data_merged.columns)
claims_data_merged_header = claims_data_merged.iloc[0]
claims_data_merged = claims_data_merged[1:]
claims_data_merged.columns = claims_data_merged_header
claims_data_merged.index.names = ['Date']
claims_data_merged.columns.names = ['']

claims_data_merged_very_low.columns = [''] * len(claims_data_merged_very_low.columns)
claims_data_merged_very_low_header = claims_data_merged_very_low.iloc[0]
claims_data_merged_very_low = claims_data_merged_very_low[1:]
claims_data_merged_very_low.columns = claims_data_merged_very_low_header
claims_data_merged_very_low.index.names = ['Date']
claims_data_merged_very_low.columns.names = ['']

claims_data_merged.head()
claims_data_merged_very_low.head()
# Out:
#            Brooks Duval Hall Maverick Menard Starr Willacy Zapata Zavala
# Date
# 11/7/2020       7    21    2      138      2   178      26     19     21
# 10/31/2020      9    10    2      241      1   124      24     20     11
# 10/24/2020      8    16    1      111      2   152      51     27     18
# 10/17/2020     13     9    4      100      0   143      43     27     12
# 10/10/2020     12    19    3       99      1   139      24     22     16

# %%
claims_data_merged.index = pd.to_datetime(claims_data_merged.index)

claims_data_merged_very_low.index = pd.to_datetime(claims_data_merged_very_low.index)

claims_data_merged.head()
# Out:
#            Anderson Angelina Aransas Atascosa Bailey Bandera Baylor Bee Bell  \
# Date
# 2020-11-07       51       83      20       57     12      18      2  34  428
# 2020-10-31       42       77      32       46      3      23      5  20  408
# 2020-10-24       79       89      22       36      1      13      2  24  359
# 2020-10-17       54       80      40       35      4      24      2  19  364
# 2020-10-10       63       98      18       40      3      11      3  41  436
#
#            Bexar  ... Ward Washington Webb Wharton Wheeler Wichita Wilbarger  \
# Date              ...
# 2020-11-07  1952  ...   24         33  241      36       9     159        20
# 2020-10-31  2002  ...   14         30  248      36       3     151        11
# 2020-10-24  1842  ...   17         24  246      49       4     159        18
# 2020-10-17  1766  ...   23         34  248      41       9     156        22
# 2020-10-10  2319  ...   19         37  318      38      10     176        24
#
# ...

# %% [markdown]
# ## Summing up the claims per month

# %%
low_income_claims_monthly = claims_data_merged.resample('M').sum()

very_low_income_claims_monthly = claims_data_merged_very_low.resample('M').sum()
very_low_income_claims_monthly.head()
# Out:
#             Brooks  Duval  Hall  Maverick  Menard   Starr  Willacy  Zapata  \
# Date
# 2020-03-31    63.0  137.0   9.0     584.0    12.0  1046.0    148.0    88.0
# 2020-04-30   159.0  281.0  28.0    1783.0    23.0  1567.0    400.0   242.0
# 2020-05-31   144.0  330.0  26.0    2064.0    20.0  1974.0    375.0   319.0
# 2020-06-30    86.0  198.0  21.0     980.0    15.0  1291.0    203.0   240.0
# 2020-07-31    93.0  156.0  20.0     962.0    20.0  1188.0    208.0   132.0
#
#             Zavala
# Date
# 2020-03-31    88.0
# 2020-04-30   169.0
# 2020-05-31   294.0
# 2020-06-30   124.0
# 2020-07-31   154.0

# %% [markdown]
# ## Setup dataframe for plotting

# %%
low_income_claims_monthly_sum  = low_income_claims_monthly.sum(axis=1) 

very_low_income_claims_monthly_sum  = very_low_income_claims_monthly.sum(axis=1) 

total_claims_per_month_df['Claims per Month Low Income'] = low_income_claims_monthly_sum

total_claims_per_month_df['Claims per Month Very Low Income'] = very_low_income_claims_monthly_sum

total_claims_per_month_df['Covid Cases per Month'] = cumulative_numbers

total_claims_per_month_df.head()
# Out:
#             Claims Per Month  Claims per Month Low Income  \
# Date
# 2020-03-31          447963.0                     139761.0
# 2020-04-30          843167.0                     273291.0
# 2020-05-31          591316.0                     198815.0
# 2020-06-30          319165.0                     110807.0
# 2020-07-31          323837.0                     118853.0
#
#             Claims per Month Very Low Income  Covid Cases per Month
# Date
# 2020-03-31                            2175.0                   3809
# 2020-04-30                            4652.0                  24918
# 2020-05-31                            5546.0                  35925
# 2020-06-30                            3158.0                  98408
# 2020-07-31                            2933.0                 275233

# %% [markdown]
# ##  Setup variables for the claims chart

# %%
date = ['MAR', 'APR', 'MAY', 'JUN','JUL', 'AUG', 'SEP', 'OCT','NOV']
claims_per_month = total_claims_per_month_df['Claims Per Month']
claims_per_month_low_income = total_claims_per_month_df['Claims per Month Low Income']
claims_per_month_very_low_income = total_claims_per_month_df['Claims per Month Very Low Income']
covid_cases_per_month = total_claims_per_month_df['Covid Cases per Month']

# %% [markdown]
# ## Plot chart

# %%
width = .35       # the width of the bars
plt.figure(figsize=(14,7))
p1 = plt.bar(date, claims_per_month, width)
p2 = plt.bar(date, claims_per_month_low_income, width)
p3 = plt.bar(date, claims_per_month_very_low_income, width)
#line plot
p4 = plt.plot(date, covid_cases_per_month)
plt.setp(p4, 'color', 'r', 'linewidth', 2.0)


plt.ylabel('Number of Claims', fontsize = 15)
plt.title('Texas Monthly Unemployment Claims 2020', fontsize = 20)
plt.xticks(date)
plt.yticks(np.arange(0, 900000, 50000))
plt.legend((p1[0], p2[0], p3[0], p4[0]), ('All Counties', 'Low Income Counties','Very Low Income Counties', 'Covid Cases'))
plt.xticks(rotation ='vertical')
plt.figure(figsize=(14,7))

plt.show()

# %%
texas_county_NCHS_urbanization = Texas_ConfirmedByCounty_Covid[['county_name','NCHS_urbanization']]
texas_county_NCHS_urbanization
# Out:
#      county_name NCHS_urbanization
# 2599    Anderson      Micropolitan
# 2600     Andrews      Micropolitan
# 2601    Angelina      Micropolitan
# 2602     Aransas      Medium metro
# 2603      Archer       Small metro
# ...          ...               ...
# 2848        Wood          Non-core
# 2849      Yoakum          Non-core
# 2850       Young          Non-core
# 2851      Zapata      Micropolitan
# 2852      Zavala          Non-core
#
# [254 rows x 2 columns]

# %%
unemployment_claims_totals_by_county_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-137-5d3aec8936ce> in <module>
# ----> 1 unemployment_claims_totals_by_county_df
#
# NameError: name 'unemployment_claims_totals_by_county_df' is not defined

# %% [markdown]
# ## merge unemployment claims by month to covid cases by NCSH urbanization

# %%
Monthly_Cases_by_NCSH_Urbanization = Texas_ConfirmedByCounty_Covid.loc[Texas_ConfirmedByCounty_Covid['NCHS_urbanization'] == 'Large central metro'].sort_values('total_population',ascending=False)

Monthly_Cases_by_NCSH_Urbanization_merged = texas_county_NCHS_urbanization.merge(unemployment_claims_totals_by_county_df, left_on='county_name', right_on='County')

#Monthly_Cases_by_NCSH_Urbanization_merged = Monthly_Cases_by_NCSH_Urbanization_merged.drop(columns=['Median Household Income'])
Monthly_Cases_by_NCSH_Urbanization_merged
# Out:
#     county_name NCHS_urbanization    County  Claims Per Month
# 0      Anderson      Micropolitan  Anderson            3902.0
# 1       Andrews      Micropolitan   Andrews            1995.0
# 2      Angelina      Micropolitan  Angelina            7930.0
# 3       Aransas      Medium metro   Aransas            2527.0
# 4        Archer       Small metro    Archer             540.0
# ..          ...               ...       ...               ...
# 248        Wood          Non-core      Wood            2980.0
# 249      Yoakum          Non-core    Yoakum             884.0
# 250       Young          Non-core     Young            1068.0
# 251      Zapata      Micropolitan    Zapata            1425.0
# 252      Zavala          Non-core    Zavala            1108.0
#
# [253 rows x 4 columns]

# %%
locations = Texas_ConfirmedByCounty_Covid[['lat','lon']]
confirmed = Texas_ConfirmedByCounty_Covid['confirmed']

# %%
zero_coor = (31.81,-95.65)
figure_layout = {'width': '1050px', 'margin': '0 auto 0 auto'}
# Plot Heatmap
fig = gmaps.figure(center=zero_coor,zoom_level=5.5,layout=figure_layout,map_type="TERRAIN")

# Create heat layer
heat_layer = gmaps.heatmap_layer(locations, weights=confirmed,
                                 dissipating=False, max_intensity=.5,
                                 point_radius=.5)

# Add layer
fig.add_layer(heat_layer)

# Display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px', margin='0 auto 0 auto', width='1050px'))

# %%
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y
