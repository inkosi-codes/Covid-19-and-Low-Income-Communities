# %% [markdown]
# ## Create Dependencies

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
import scipy.stats as st
import numpy as np
import requests as rq
import random as rnd
import gmaps
import os
import io
import json
import time
from datetime import datetime
# Import API key
#import config

# Configure gmaps
gkey = config.gkey
gmaps.configure(api_key=gkey)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-403-6d862045ac6c> in <module>
#      17
#      18 # Configure gmaps
# ---> 19 gkey = config.gkey
#      20 gmaps.configure(api_key=gkey)
#
# NameError: name 'config' is not defined

# %% [markdown]
# ## Create and set the path

# %%
notebook_path = os.getcwd()
parent_dir = notebook_path[0:-4]

# %% [markdown]
# ## Store csv filenames. Iterate through the filename list and get csv from path and store in variables

# %%
dataset_filelist = ["1_county_level_confirmed_cases.csv","2_cases_and_deaths_by_county_timeseries.csv","weekly-claims-by-county-twc.csv","texas_county_med_income.csv"]
for csv in dataset_filelist:   
    for root, dirs, files in os.walk(parent_dir):
        if csv in files:
            if csv == dataset_filelist[0]:
                covid_dataset1 = (os.path.join(root, csv))
            elif csv == dataset_filelist[1]:
               covid_dataset2 =  (os.path.join(root, csv))
            elif csv == dataset_filelist[2]:
               unemployment_dataset =  (os.path.join(root, csv))
            else:
                texas_median_income = (os.path.join(root, csv))

# %% [markdown]
# ## Use pandas and read contents of csv into a DataFrame

# %%
ConfirmedByCounty_Covid = pd.read_csv('https://query.data.world/s/tmtcsyi5cadisfgsziloo4c7sesaon')
CaseDeathsBy_County_timeseries = pd.read_csv('https://query.data.world/s/ipaqguramdyfp27ppx72n3sgtkj6xu', parse_dates=['date'])
unemployment_dataset = pd.read_csv(unemployment_dataset)
texas_median_income = pd.read_csv(texas_median_income)

# %% [markdown]
# ## Remove ("$",",") characters from the Texas Median Income dataset and convert to float

# %%
texas_median_income['Median Household Income'] = texas_median_income['Median Household Income'].str.replace('$','').str.replace(',','').astype(float)

# %%
texas_median_income.head()
# Out:
#      County  Median Household Income
# 0  Anderson                  45969.0
# 1   Andrews                  84946.0
# 2  Angelina                  46653.0
# 3   Aransas                  46912.0
# 4    Archer                  61190.0

# %%
texas_low_income = texas_median_income.loc[(texas_median_income['Median Household Income'] > 57000)]
texas_low_income.describe()
# Out:
#        Median Household Income
# count                56.000000
# mean              69560.303571
# std               11444.745846
# min               57052.000000
# 25%               60789.500000
# 50%               66080.000000
# 75%               76322.000000
# max              102858.000000

# %% [markdown]
# ## Incomes that qualify as low imcome per HUD data. Less than or equal to 57K but greater than 36K

# %%
texas_low_income = texas_median_income.loc[(texas_median_income['Median Household Income'] <= 57000) & (texas_median_income['Median Household Income'] > 36000)]
texas_low_income.head()
# Out:
#      County  Median Household Income
# 0  Anderson                  45969.0
# 2  Angelina                  46653.0
# 3   Aransas                  46912.0
# 6  Atascosa                  50594.0
# 8    Bailey                  45051.0

# %% [markdown]
# ## Incomes that qualify as very low imcome per HUD data. Less than or equal to 36K but greater than 26K

# %%
texas_verylow_income = texas_median_income.loc[(texas_median_income['Median Household Income'] <= 36000) & (texas_median_income['Median Household Income'] > 26000)]
texas_verylow_income.head()
# Out:
#        County  Median Household Income
# 23     Brooks                  30116.0
# 65      Duval                  35156.0
# 95       Hall                  32597.0
# 161  Maverick                  35594.0
# 163    Menard                  35881.0

# %% [markdown]
# ## Covid-19 Dataset that gives most recent case and death numbers as of 2020-11-13
# * Cleansed Data to get rid of one row in Latitude and Longitude that had NaN

# %%
Texas_ConfirmedByCounty_Covid = ConfirmedByCounty_Covid.loc[ConfirmedByCounty_Covid['state'] == 'Texas'].dropna(subset=['lat','lon'])
Texas_ConfirmedByCounty_Covid.head()
# Out:
#                   last_update location_type  state county_name  \
# 2599  2020-11-18 03:26:18 UTC        county  Texas    Anderson
# 2600  2020-11-18 03:26:18 UTC        county  Texas     Andrews
# 2601  2020-11-18 03:26:18 UTC        county  Texas    Angelina
# 2602  2020-11-18 03:26:18 UTC        county  Texas     Aransas
# 2603  2020-11-18 03:26:18 UTC        county  Texas      Archer
#
#          county_name_long  fips_code        lat         lon NCHS_urbanization  \
# 2599  Anderson, Texas, US    48001.0  31.815347  -95.653548      Micropolitan
# 2600   Andrews, Texas, US    48003.0  32.304686 -102.637655      Micropolitan
# 2601  Angelina, Texas, US    48005.0  31.254573  -94.609015      Micropolitan
# 2602   Aransas, Texas, US    48007.0  28.105562  -96.999505      Medium metro
# 2603    Archer, Texas, US    48009.0  33.615700  -98.687546       Small metro
#
#       total_population  confirmed  confirmed_per_100000  deaths  \
# 2599           57863.0       3065               5296.99      45
# 2600           17818.0        896               5028.62      12
# 2601           87607.0       2446               2792.01      95
# 2602           24763.0        375               1514.36      18
# 2603            8789.0        207               2355.22       2
#
#       deaths_per_100000
# 2599              77.77
# 2600              67.35
# 2601             108.44
# 2602              72.69
# 2603              22.76

# %%
Texas_ConfirmedByCounty_Covid = Texas_ConfirmedByCounty_Covid.drop(columns=["location_type","state","county_name_long","fips_code"])

# %%
covid_cumlative_groupby = Texas_ConfirmedByCounty_Covid.groupby('NCHS_urbanization')
covid_cumlative_groupby['county_name'].count()
# Out:
# NCHS_urbanization
# Large central metro      6
# Large fringe metro      29
# Medium metro            25
# Micropolitan            46
# Non-core               126
# Small metro             22
# Name: county_name, dtype: int64

# %%
Texas_ConfirmedByCounty_Covid.loc[Texas_ConfirmedByCounty_Covid['NCHS_urbanization'] == 'Large central metro'].sort_values('total_population',ascending=False)
# Out:
#                   last_update county_name        lat        lon  \
# 2699  2020-11-18 03:26:18 UTC      Harris  29.858649 -95.393395
# 2655  2020-11-18 03:26:18 UTC      Dallas  32.766706 -96.777960
# 2818  2020-11-18 03:26:18 UTC     Tarrant  32.771438 -97.291016
# 2613  2020-11-18 03:26:18 UTC       Bexar  29.449287 -98.520197
# 2825  2020-11-18 03:26:18 UTC      Travis  30.334320 -97.785356
# 2641  2020-11-18 03:26:18 UTC      Collin  33.188201 -96.572644
#
#         NCHS_urbanization  total_population  confirmed  confirmed_per_100000  \
# 2699  Large central metro         4602523.0     175959               3823.10
# 2655  Large central metro         2586552.0     111174               4298.15
# 2818  Large central metro         2019977.0      83647               4140.99
# 2613  Large central metro         1925865.0      70528               3662.15
# 2825  Large central metro         1203166.0      35020               2910.65
# 2641  Large central metro          944350.0      21689               2296.71
#
#       deaths  deaths_per_100000
# 2699    2919              63.42
# 2655    1391              53.78
# 2818     943              46.68
# 2613    1453              75.45
# 2825     469              38.98
# 2641     222              23.51

# %%
combined = covid_cumlative_groupby['confirmed','deaths'].sum()
combined.plot(kind='bar', stacked=True)
# Out:
# C:\Users\mike1\anaconda3\envs\VirCondaEnv\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
# <AxesSubplot:xlabel='NCHS_urbanization'>

# %%
urban_death = covid_cumlative_groupby['deaths'].mean()

# %%
urban_death
# Out:
# NCHS_urbanization
# Large central metro    1232.833333
# Large fringe metro       79.517241
# Medium metro            238.280000
# Micropolitan             42.586957
# Non-core                 10.031746
# Small metro              57.454545
# Name: deaths, dtype: float64

# %%
urban_cases.plot.bar()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-420-31bd5f2445fa> in <module>
# ----> 1 urban_cases.plot.bar()
#
# NameError: name 'urban_cases' is not defined

# %%
covid_cumlative_groupby['confirmed'].mean()
# Out:
# NCHS_urbanization
# Large central metro    83002.833333
# Large fringe metro      4921.482759
# Medium metro           10556.680000
# Micropolitan            1445.065217
# Non-core                 349.992063
# Small metro             2893.000000
# Name: confirmed, dtype: float64

# %% [markdown]
# ## Select only data related to the state of Texas and drop all column with headers starting with "new"

# %%
columns_todrop = []
Texas_CaseDeathsBy_County_timeseries = CaseDeathsBy_County_timeseries.loc[(CaseDeathsBy_County_timeseries['state'] == 'Texas') & (CaseDeathsBy_County_timeseries['location_name'] != 'Unassigned') & (CaseDeathsBy_County_timeseries['location_name'] != 'Out of TX')]
Texas_CaseDeathsBy_County_timeseries = Texas_CaseDeathsBy_County_timeseries.loc[Texas_CaseDeathsBy_County_timeseries['date'] >= '2020-03-01']
for column in Texas_CaseDeathsBy_County_timeseries.columns:
    if column.startswith('new'):
        columns_todrop.append(column)
for drop in columns_todrop:
    Texas_CaseDeathsBy_County_timeseries = Texas_CaseDeathsBy_County_timeseries.drop(columns=drop)
Texas_CaseDeathsBy_County_timeseries.head()
# Out:
#              uid location_type  fips_code location_name  state       date  \
# 780939  84048001        county    48001.0      Anderson  Texas 2020-03-01
# 780940  84048001        county    48001.0      Anderson  Texas 2020-03-02
# 780941  84048001        county    48001.0      Anderson  Texas 2020-03-03
# 780942  84048001        county    48001.0      Anderson  Texas 2020-03-04
# 780943  84048001        county    48001.0      Anderson  Texas 2020-03-05
#
#         total_population  cumulative_cases  cumulative_cases_per_100_000  \
# 780939           57863.0                 0                           0.0
# 780940           57863.0                 0                           0.0
# 780941           57863.0                 0                           0.0
# 780942           57863.0                 0                           0.0
# 780943           57863.0                 0                           0.0
#
#         cumulative_deaths  cumulative_deaths_per_100_000
# 780939                  0                            0.0
# 780940                  0                            0.0
# 780941                  0                            0.0
# 780942                  0                            0.0
# 780943                  0                            0.0

# %% [markdown]
# ## Drop all other unused columns

# %%
Texas_CaseDeathsBy_County_timeseries = Texas_CaseDeathsBy_County_timeseries.drop(columns=["uid","location_type","state"]).set_index('date')

# %%
Texas_CaseDeathsBy_County_timeseries
# Out:
#             fips_code location_name  total_population  cumulative_cases  \
# date
# 2020-03-01    48001.0      Anderson           57863.0                 0
# 2020-03-02    48001.0      Anderson           57863.0                 0
# 2020-03-03    48001.0      Anderson           57863.0                 0
# 2020-03-04    48001.0      Anderson           57863.0                 0
# 2020-03-05    48001.0      Anderson           57863.0                 0
# ...               ...           ...               ...               ...
# 2020-11-12    48507.0        Zavala           12131.0               498
# 2020-11-13    48507.0        Zavala           12131.0               501
# 2020-11-14    48507.0        Zavala           12131.0               527
# 2020-11-15    48507.0        Zavala           12131.0               527
# 2020-11-16    48507.0        Zavala           12131.0               527
#
#             cumulative_cases_per_100_000  cumulative_deaths  \
# date
# 2020-03-01                          0.00                  0
# 2020-03-02                          0.00                  0
# 2020-03-03                          0.00                  0
# 2020-03-04                          0.00                  0
# 2020-03-05                          0.00                  0
# ...                                  ...                ...
# 2020-11-12                       4105.19                 21
# 2020-11-13                       4129.92                 21
# 2020-11-14                       4344.24                 21
# 2020-11-15                       4344.24                 21
# 2020-11-16                       4344.24                 21
#
#             cumulative_deaths_per_100_000
# date
# 2020-03-01                           0.00
# 2020-03-02                           0.00
# 2020-03-03                           0.00
# 2020-03-04                           0.00
# 2020-03-05                           0.00
# ...                                   ...
# 2020-11-12                         173.11
# 2020-11-13                         173.11
# 2020-11-14                         173.11
# 2020-11-15                         173.11
# 2020-11-16                         173.11
#
# [66294 rows x 7 columns]

# %%
Texas_CaseDeathsBy_County_timeseries_lastday = Texas_CaseDeathsBy_County_timeseries['2020-10-31']

# %% [markdown]
# ## Unemployment Data

# %%
unemployment_claims = unemployment_dataset.copy()
unemployment_claims = unemployment_claims.transpose()
unemployment_claims = unemployment_claims.fillna(0)

# %%
unemployment_claims.columns = [''] * len(unemployment_claims.columns)
unemployment_header = unemployment_claims.iloc[0]
unemployment_claims = unemployment_claims[1:]
unemployment_claims.columns = unemployment_header
unemployment_claims.index.names = ['Date']
unemployment_claims.columns.names = ['']
unemployment_claims
# Out:
#             Anderson Andrews Angelina Aransas Archer Armstrong Atascosa  \
# Date
# 11/7/2020         51      12       83      20      5         0       57
# 10/31/2020        42      17       77      32      3         1       46
# 10/24/2020        79      17       89      22      6         0       36
# 10/17/2020        54      17       80      40      5         1       35
# 10/10/2020        63      30       98      18     10         2       40
# 10/3/2020         64      25      103      26      6         1       55
# 9/26/2020         64      21      100      35      5         1       56
# 9/19/2020         61      18      119      25      4         0       70
# 9/12/2020         66      32      107      31      5         0       67
# 9/5/2020          85      22      171      50      6         3       96
# 8/29/2020         91      19      170      47      4         0       76
# 8/22/2020         96      34      157      45      8         5       96
# 8/15/2020         84      29      188      65     12         2       97
# 8/8/2020          92      33      147      38      5         3       66
#  8/1/2020         99      36      131      48     10         1       89
#  7/25/2020       104      45      204      59     11         3      113
#  7/18/2020        85      48      235      63     18         2      143
# 7/11/2020        147      67      258      85     13         3      147
# 7/4/2020         131      75      218      92     23         1      149
# 6/27/2020        103      43      187      70     13         0      129
# 6/20/2020        100      68      219      58      7         3      127
# 6/13/2020        108      50      201      63     11         2      147
# 6/6/2020         115      52      252      76     17         1      133
# 5/30/2020        134      61      250      59     12         2      119
# 5/23/2020        192      71      272      74     24         2      172
# 5/16/2020        123      94      304      80     23         4      194
# 5/9/2020         153      96      273      92     20         2      190
# 5/2/2020         181     117      463     154     32         5      291
# 4/25/2020        176     133      388     109     24         0      265
# 4/18/2020        183     143      449     160     41         5      302
# 4/11/2020        205     165      495     155     34        15      346
# 4/4/2020         252     143      689     230     58         6      409
# 3/28/2020        180      95      452     217     42         6      325
# 3/21/2020        101      50      227      70     20         1      177
# 3/14/2020         18      16       37      10      1         0       31
# 3/7/2020          20       1       37       9      2         2       20
#
#             Austin Bailey Bandera  ... Willacy Williamson Wilson Winkler Wise  \
# Date                               ...
# 11/7/2020       29     12      18  ...      26        455     32      11   52
# 10/31/2020      28      3      23  ...      24        422     28       7   74
# 10/24/2020      23      1      13  ...      51        409     34       8   65
# 10/17/2020      26      4      24  ...      43        434     30      15   45
# 10/10/2020      32      3      11  ...      24        484     41      11   57
# 10/3/2020       37      5      18  ...      15        574     41      12   79
# 9/26/2020       30      4      22  ...      26        564     39      18   59
# 9/19/2020       29      3      25  ...      23        526     42      13   59
# 9/12/2020       42      8       4  ...      19        524     41       8   51
# 9/5/2020        45      9      41  ...      29        800     54      19   86
# 8/29/2020       41      3      20  ...      29        654     45      12   77
# 8/22/2020       40      3      18  ...      28        630     46      22   82
# 8/15/2020       39      6      25  ...      40        678     60      19   84
# 8/8/2020        31      2      29  ...      49        641     53      14   66
#  8/1/2020       47      5      29  ...      47        678     55      14   80
#  7/25/2020      67      8      28  ...      43        838     86      26  104
#  7/18/2020      65      4      28  ...      38       1024     92      25  118
# 7/11/2020       61      8      44  ...      67       1202    109      35  152
# 7/4/2020        89     10      47  ...      60       1390    109      40  157
# 6/27/2020       51      6      39  ...      55       1149     63      32  142
# 6/20/2020       56      6      34  ...      42       1052    105      38  130
# 6/13/2020       57      3      34  ...      56        985     77      44  147
# 6/6/2020        49      5      27  ...      50       1130    100      33  177
# 5/30/2020       64      5      37  ...      72       1260    115      31  178
# 5/23/2020       85      6      54  ...      81       1537    132      51  196
# 5/16/2020       82      6      46  ...      75       1563    139      35  165
# 5/9/2020        72      5      53  ...      71       2016    184      37  247
# 5/2/2020       107      8      71  ...      76       2518    219      78  321
# 4/25/2020      114     10      82  ...      71       2735    193      56  236
# 4/18/2020      120     13      80  ...     101       3738    211      48  344
# 4/11/2020      122     10      81  ...     119       4848    236      50  368
# 4/4/2020       170     13     152  ...     109       5720    280      41  457
# 3/28/2020      109     11     117  ...      82       5725    242      41  457
# 3/21/2020      100      3      51  ...      35       3810    142      15  244
# 3/14/2020       28      4       4  ...      10        253     22       8   25
# 3/7/2020        17      3       5  ...      21        203     13       7  123
#
#             Wood Yoakum Young Zapata Zavala
# Date
# 11/7/2020     39      8    12     19     21
# 10/31/2020    31     14    16     20     11
# 10/24/2020    33      8    17     27     18
# 10/17/2020    26      6    17     27     12
# 10/10/2020    38      6    19     22     16
# 10/3/2020     45      9    11     19     16
# 9/26/2020     46      7    18     29     11
# 9/19/2020     29      5     7     23     21
# 9/12/2020     56     12    13     23     20
# 9/5/2020      83     10    22     34     18
# 8/29/2020     53     11    12     37     21
# 8/22/2020     37     10    15     34     43
# 8/15/2020     48     13    19     40     17
# 8/8/2020      68      3    18     24     18
#  8/1/2020     51      8    24     26     16
#  7/25/2020    69     13    20     32     32
#  7/18/2020    87     19    18     31     34
# 7/11/2020     78     10    29     30     45
# 7/4/2020      90     13    36     39     43
# 6/27/2020     74     16    35     61     23
# 6/20/2020     74     14    32     68     35
# 6/13/2020     57     16    23     48     25
# 6/6/2020      89     22    24     63     41
# 5/30/2020     89     18    30     59     48
# 5/23/2020     91     31    29     56     60
# 5/16/2020    123     63    46     42     45
# 5/9/2020     135     46    39     73     79
# 5/2/2020     142     63    52     89     62
# 4/25/2020    130     57    43     57     57
# 4/18/2020    160     84    60     59     41
# 4/11/2020    219     75    91     55     30
# 4/4/2020     287    101    95     71     41
# 3/28/2020    201     53    84     45     47
# 3/21/2020     73     27    31     29     27
# 3/14/2020     15     11     9      7      7
# 3/7/2020      14      2     2      7      7
#
# [36 rows x 254 columns]

# %%
unemployment_claims.index = pd.to_datetime(unemployment_claims.index)
unemployment_claims.head()
# Out:
#            Anderson Andrews Angelina Aransas Archer Armstrong Atascosa Austin  \
# Date
# 2020-11-07       51      12       83      20      5         0       57     29
# 2020-10-31       42      17       77      32      3         1       46     28
# 2020-10-24       79      17       89      22      6         0       36     23
# 2020-10-17       54      17       80      40      5         1       35     26
# 2020-10-10       63      30       98      18     10         2       40     32
#
#            Bailey Bandera  ... Willacy Williamson Wilson Winkler Wise Wood  \
# Date                       ...
# 2020-11-07     12      18  ...      26        455     32      11   52   39
# 2020-10-31      3      23  ...      24        422     28       7   74   31
# 2020-10-24      1      13  ...      51        409     34       8   65   33
# 2020-10-17      4      24  ...      43        434     30      15   45   26
# 2020-10-10      3      11  ...      24        484     41      11   57   38
#
#            Yoakum Young Zapata Zavala
# Date
# 2020-11-07      8    12     19     21
# 2020-10-31     14    16     20     11
# 2020-10-24      8    17     27     18
# 2020-10-17      6    17     27     12
# 2020-10-10      6    19     22     16
#
# [5 rows x 254 columns]

# %%
unemployment_claims.resample('M').sum()
# Out:
#             Anderson  Andrews  Angelina  Aransas  Archer  Armstrong  Atascosa  \
# Date
# 2020-03-31     319.0    162.0     753.0    306.0    65.0        9.0     553.0
# 2020-04-30     816.0    584.0    2021.0    654.0   157.0       26.0    1322.0
# 2020-05-31     783.0    439.0    1562.0    459.0   111.0       15.0     966.0
# 2020-06-30     426.0    213.0     859.0    267.0    48.0        6.0     536.0
# 2020-07-31     467.0    235.0     915.0    299.0    65.0        9.0     552.0
# 2020-08-31     462.0    151.0     793.0    243.0    39.0       11.0     424.0
# 2020-09-30     276.0     93.0     497.0    141.0    20.0        4.0     289.0
# 2020-10-31     302.0    106.0     447.0    138.0    30.0        5.0     212.0
# 2020-11-30      51.0     12.0      83.0     20.0     5.0        0.0      57.0
#
#             Austin  Bailey  Bandera  ...  Willacy  Williamson  Wilson  \
# Date                                 ...
# 2020-03-31   254.0    21.0    177.0  ...    148.0      9991.0   419.0
# 2020-04-30   526.0    46.0    395.0  ...    400.0     17041.0   920.0
# 2020-05-31   410.0    30.0    261.0  ...    375.0      8894.0   789.0
# 2020-06-30   213.0    20.0    134.0  ...    203.0      4316.0   345.0
# 2020-07-31   282.0    30.0    147.0  ...    208.0      4454.0   396.0
# 2020-08-31   198.0    19.0    121.0  ...    193.0      3281.0   259.0
# 2020-09-30   146.0    24.0     92.0  ...     97.0      2414.0   176.0
# 2020-10-31   146.0    16.0     89.0  ...    157.0      2323.0   174.0
# 2020-11-30    29.0    12.0     18.0  ...     26.0       455.0    32.0
#
#             Winkler    Wise   Wood  Yoakum  Young  Zapata  Zavala
# Date
# 2020-03-31     71.0   849.0  303.0    93.0  126.0    88.0    88.0
# 2020-04-30    195.0  1405.0  796.0   317.0  289.0   242.0   169.0
# 2020-05-31    232.0  1107.0  580.0   221.0  196.0   319.0   294.0
# 2020-06-30    147.0   596.0  294.0    68.0  114.0   240.0   124.0
# 2020-07-31    126.0   531.0  324.0    55.0  103.0   132.0   154.0
# 2020-08-31     81.0   389.0  257.0    45.0   88.0   161.0   115.0
# 2020-09-30     58.0   255.0  214.0    34.0   60.0   109.0    70.0
# 2020-10-31     53.0   320.0  173.0    43.0   80.0   115.0    73.0
# 2020-11-30     11.0    52.0   39.0     8.0   12.0    19.0    21.0
#
# [9 rows x 254 columns]

# %%
#get months 
claims_resample_by_month = unemployment_claims.resample('M').sum()
monthly_claims_date_list = claims_resample_by_month.index.tolist()
monthly_claims_date_list
#claims_resample_by_month.sum (axis=1)
# Out:
# [Timestamp('2020-03-31 00:00:00', freq='M'),
#  Timestamp('2020-04-30 00:00:00', freq='M'),
#  Timestamp('2020-05-31 00:00:00', freq='M'),
#  Timestamp('2020-06-30 00:00:00', freq='M'),
#  Timestamp('2020-07-31 00:00:00', freq='M'),
#  Timestamp('2020-08-31 00:00:00', freq='M'),
#  Timestamp('2020-09-30 00:00:00', freq='M'),
#  Timestamp('2020-10-31 00:00:00', freq='M'),
#  Timestamp('2020-11-30 00:00:00', freq='M')]

# %%
claims_monthly_totals = claims_resample_by_month.sum(axis=1)
claims_monthly_totals
# Out:
# Date
# 2020-03-31    447963.0
# 2020-04-30    843167.0
# 2020-05-31    591316.0
# 2020-06-30    319165.0
# 2020-07-31    323837.0
# 2020-08-31    246138.0
# 2020-09-30    165862.0
# 2020-10-31    170999.0
# 2020-11-30     32887.0
# Freq: M, dtype: float64

# %%
total_claims_per_month_df = pd.DataFrame({'Claims Per Month': claims_monthly_totals})
#print(total_claims_per_month_df['Date'])

total_claims_per_month_df.head()
# Out:
#             Claims Per Month
# Date
# 2020-03-31          447963.0
# 2020-04-30          843167.0
# 2020-05-31          591316.0
# 2020-06-30          319165.0
# 2020-07-31          323837.0

# %% [markdown]
# ## Unemployment charts start here

# %%
#setup data for line chart

date = monthly_claims_date_list
claims_per_month = total_claims_per_month_df['Claims Per Month']

#these are cumuliative values...need to get end of month numbers from Jazlyn's table
cases_deaths_sum = Texas_CaseDeathsBy_County_timeseries.resample('M').sum()
cases_deaths_sum

monthly_cases = cases_deaths_sum[['cumulative_cases']]
monthly_deaths = cases_deaths_sum[['cumulative_deaths']]

# %%
x = date
y = claims_per_month
z = monthly_cases



fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(x,y, '-', label = 'Unemployment Claims Per Month')
plt.xticks(rotation ='vertical')
ax2 = ax.twinx()
ax2.plot(x,z, '-r', label = 'Covid Cases Per Month')
fig.legend(loc=1)

ax.set_xlabel("Months")
ax.set_ylabel(r"Claims")
ax2.set_ylabel(r"Covid Cases (thousands)")
# Out:
# Text(0, 0.5, 'Covid Cases (thousands)')

# %%
#bar chart of claims per week


# plot bar chart
plt.figure(figsize=(14,7))
plt.bar(date, claims_per_month, width = 8)
#plt.bar(date, total_per_month, width = .65)
plt.xlabel("Month")
plt.ylabel("Number of Claims")
plt.title("Unemployment Claims Per Month")
plt.xticks(rotation ='vertical')

#line plot
# lines = plt.plot(date, monthly_cases)
# plt.setp(lines, 'color', 'r', 'linewidth', 2.0)


plt.show()

# %%
locations = Texas_ConfirmedByCounty_Covid[['lat','lon']]
confirmed = Texas_ConfirmedByCounty_Covid['confirmed']

# %%
zero_coor = (31.81,-95.65)
figure_layout = {'width': '1050px', 'margin': '0 auto 0 auto'}
# Plot Heatmap
fig = gmaps.figure(center=zero_coor,zoom_level=5.5,layout=figure_layout,map_type="TERRAIN")

# Create heat layer
heat_layer = gmaps.heatmap_layer(locations, weights=confirmed,
                                 dissipating=False, max_intensity=.5,
                                 point_radius=.5)

# Add layer
fig.add_layer(heat_layer)

# Display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px', margin='0 auto 0 auto', width='1050px'))

# %%
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y
